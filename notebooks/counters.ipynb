# %%
import sys
import pandas as pd
sys.path.append("..")
from src.models.utils.dataset_preprocess import preprocess_dataset

# %%
# %load_ext autoreload
# %autoreload 2

# %%
preprocess_dataset()

# %% [markdown]
# ### Resultados onlyzeros

# %%
df_test_results = pd.read_csv('C:\\Users\\gregf\\Desktop\\UFSCAR\\2022-2\IA 2\\RecomendadorArtes\\src\\models\\model_saves\\OnlyZeros\\results\\17_03_2023_16_15\\all_classes_results.csv')

# %%
df_test_results
# Out:
#                      genre  accuracy  precision  recall   f1  \
# 0            Byzantine Art  0.988180        0.0     0.0  0.0
# 1           Abstractionism  0.969267        0.0     0.0  0.0
# 2            Impressionism  0.768322        0.0     0.0  0.0
# 3              Art Nouveau  0.985816        0.0     0.0  0.0
# 4              Suprematism  0.985816        0.0     0.0  0.0
# 5              Romanticism  0.952719        0.0     0.0  0.0
# 6   Abstract Expressionism  0.997636        0.0     0.0  0.0
# 7                  Realism  0.981087        0.0     0.0  0.0
# 8        Early Renaissance  0.981087        0.0     0.0  0.0
# 9                  Pop Art  0.978723        0.0     0.0  0.0
# 10    Northern Renaissance  0.919622        0.0     0.0  0.0
# 11                  Cubism  0.947991        0.0     0.0  0.0
# 12               Mannerism  0.959811        0.0     0.0  0.0
# 13      Post-Impressionism  0.806147        0.0     0.0  0.0
# ...

# %%
df_test_results[['true positives', 'false positives']].sum()
# Out:
# true positives     0.0
# false positives    0.0
# dtype: float64

# %%
df_train_results = pd.read_csv('C:\\Users\\gregf\\Desktop\\UFSCAR\\2022-2\\IA 2\\RecomendadorArtes\\src\\models\\model_saves\\OnlyZeros\\results\\17_03_2023_16_16\\all_classes_results_train.csv')

# %%
df_train_results
# Out:
#                      genre  accuracy  precision  recall   f1  \
# 0            Byzantine Art  0.988284        0.0     0.0  0.0
# 1           Abstractionism  0.967219        0.0     0.0  0.0
# 2            Impressionism  0.771532        0.0     0.0  0.0
# 3              Art Nouveau  0.986165        0.0     0.0  0.0
# 4              Suprematism  0.985043        0.0     0.0  0.0
# 5              Romanticism  0.954132        0.0     0.0  0.0
# 6   Abstract Expressionism  0.997133        0.0     0.0  0.0
# 7                  Realism  0.982426        0.0     0.0  0.0
# 8        Early Renaissance  0.980556        0.0     0.0  0.0
# 9                  Pop Art  0.978562        0.0     0.0  0.0
# 10    Northern Renaissance  0.919481        0.0     0.0  0.0
# 11                  Cubism  0.948024        0.0     0.0  0.0
# 12               Mannerism  0.959491        0.0     0.0  0.0
# 13      Post-Impressionism  0.806307        0.0     0.0  0.0
# ...

# %%
df_train_results[['true positives', 'false positives']].sum()
# Out:
# true positives     0.0
# false positives    0.0
# dtype: float64

# %% [markdown]
# ### Resultados Random

# %%
df_test_results = pd.read_csv('C:\\Users\\gregf\\Desktop\\UFSCAR\\2022-2\\IA 2\\RecomendadorArtes\\src\\models\\model_saves\\Random\\results\\17_03_2023_16_44\\all_classes_results.csv')

# %%
df_test_results
# Out:
#                      genre  accuracy  precision    recall        f1  \
# 0            Byzantine Art  0.910165   0.000000  0.000000  0.000000
# 1           Abstractionism  0.919622   0.043478  0.076923  0.055556
# 2            Impressionism  0.737589   0.217391  0.051020  0.082645
# 3              Art Nouveau  0.940898   0.000000  0.000000  0.000000
# 4              Suprematism  0.933806   0.000000  0.000000  0.000000
# 5              Romanticism  0.898345   0.000000  0.000000  0.000000
# 6   Abstract Expressionism  0.950355   0.000000  0.000000  0.000000
# 7                  Realism  0.933806   0.045455  0.125000  0.066667
# 8        Early Renaissance  0.950355   0.000000  0.000000  0.000000
# 9                  Pop Art  0.940898   0.000000  0.000000  0.000000
# 10    Northern Renaissance  0.877069   0.050000  0.029412  0.037037
# 11                  Cubism  0.912530   0.058824  0.045455  0.051282
# 12               Mannerism  0.903073   0.071429  0.117647  0.088889
# ...

# %%
df_test_results[['true positives', 'false positives']].sum()
# Out:
# true positives      24.0
# false positives    506.0
# dtype: float64

# %%
df_train_results = pd.read_csv('C:\\Users\\gregf\\Desktop\\UFSCAR\\2022-2\\IA 2\\RecomendadorArtes\\src\\models\\model_saves\\Random\\results\\17_03_2023_16_47\\all_classes_results_train.csv')

# %%
df_train_results
# Out:
#                      genre  accuracy  precision    recall        f1  \
# 0            Byzantine Art  0.938302   0.009780  0.042553  0.015905
# 1           Abstractionism  0.918858   0.029126  0.045627  0.035556
# 2            Impressionism  0.743487   0.227603  0.051282  0.083704
# 3              Art Nouveau  0.935934   0.002469  0.009009  0.003876
# 4              Suprematism  0.932444   0.016055  0.058333  0.025180
# 5              Romanticism  0.904275   0.043379  0.051630  0.047146
# 6   Abstract Expressionism  0.948897   0.002571  0.043478  0.004854
# 7                  Realism  0.930201   0.013921  0.042553  0.020979
# 8        Early Renaissance  0.929827   0.018913  0.051282  0.027634
# 9                  Pop Art  0.926960   0.029545  0.075581  0.042484
# 10    Northern Renaissance  0.878474   0.058981  0.034056  0.043180
# 11                  Cubism  0.904151   0.053299  0.050360  0.051788
# 12               Mannerism  0.911130   0.038095  0.049231  0.042953
# ...

# %%
df_train_results[['true positives', 'false positives']].sum()
# Out:
# true positives      467.0
# false positives    9370.0
# dtype: float64

# %% [markdown]
# ### Resultados KNN

# %%
df_test_results = pd.read_csv('C:\\Users\\gregf\\Desktop\\UFSCAR\\2022-2\\IA 2\\RecomendadorArtes\\src\\models\\model_saves\\KNN\\results\\16_03_2023_10_07\\all_classes_results.csv')

# %%
df_test_results
# Out:
#                      genre  accuracy  precision    recall        f1  \
# 0            Byzantine Art  0.988180   0.000000  0.000000  0.000000
# 1           Abstractionism  0.969267   0.000000  0.000000  0.000000
# 2            Impressionism  0.754137   0.450000  0.275510  0.341772
# 3              Art Nouveau  0.950355   0.000000  0.000000  0.000000
# 4              Suprematism  0.985816   0.000000  0.000000  0.000000
# 5              Romanticism  0.962175   0.833333  0.250000  0.384615
# 6   Abstract Expressionism  0.997636   0.000000  0.000000  0.000000
# 7                  Realism  0.981087   0.000000  0.000000  0.000000
# 8        Early Renaissance  0.981087   0.000000  0.000000  0.000000
# 9                  Pop Art  0.978723   0.000000  0.000000  0.000000
# 10    Northern Renaissance  0.905437   0.416667  0.441176  0.428571
# 11                  Cubism  0.947991   0.000000  0.000000  0.000000
# 12               Mannerism  0.959811   0.500000  0.058824  0.105263
# ...

# %%
df_test_results[['true positives', 'false positives']].sum()
# Out:
# true positives      86.0
# false positives    143.0
# dtype: float64

# %%
df_train_results = pd.read_csv('C:\\Users\\gregf\\Desktop\\UFSCAR\\2022-2\\IA 2\\RecomendadorArtes\\src\\models\\model_saves\\KNN\\results\\16_03_2023_14_19\\all_classes_results_train.csv')

# %%
df_train_results
# Out:
#                      genre  accuracy  precision    recall        f1  \
# 0            Byzantine Art  0.988658   1.000000  0.031915  0.061856
# 1           Abstractionism  0.968964   0.937500  0.057034  0.107527
# 2            Impressionism  0.817400   0.670055  0.395526  0.497427
# 3              Art Nouveau  0.973825   0.172185  0.234234  0.198473
# 4              Suprematism  0.985542   0.833333  0.041667  0.079365
# 5              Romanticism  0.962732   0.879121  0.217391  0.348584
# 6   Abstract Expressionism  0.997133   0.000000  0.000000  0.000000
# 7                  Realism  0.982426   0.000000  0.000000  0.000000
# 8        Early Renaissance  0.980681   1.000000  0.006410  0.012739
# 9                  Pop Art  0.978811   1.000000  0.011628  0.022989
# 10    Northern Renaissance  0.927334   0.553120  0.507740  0.529459
# 11                  Cubism  0.949769   0.791667  0.045564  0.086168
# 12               Mannerism  0.962732   0.760000  0.116923  0.202667
# ...

# %%
df_train_results[['true positives', 'false positives']].sum()
# Out:
# true positives     2403.0
# false positives    1653.0
# dtype: float64

# %% [markdown]
# ### Resultados SimpleNet

# %%
df_test_results = pd.read_csv('C:\\Users\\gregf\\Desktop\\UFSCAR\\2022-2\\IA 2\\RecomendadorArtes\\src\\models\\model_saves\\SimpleNeuralNetwork\\results\\16_03_2023_09_22\\all_classes_results.csv')

# %%
df_test_results
# Out:
#                      genre  accuracy  precision    recall        f1  \
# 0            Byzantine Art  0.985816   0.000000  0.000000  0.000000
# 1           Abstractionism  0.969267   0.000000  0.000000  0.000000
# 2            Impressionism  0.768322   0.500000  0.326531  0.395062
# 3              Art Nouveau  0.985816   0.000000  0.000000  0.000000
# 4              Suprematism  0.981087   0.000000  0.000000  0.000000
# 5              Romanticism  0.955083   0.571429  0.200000  0.296296
# 6   Abstract Expressionism  0.995272   0.000000  0.000000  0.000000
# 7                  Realism  0.978723   0.000000  0.000000  0.000000
# 8        Early Renaissance  0.973995   0.000000  0.000000  0.000000
# 9                  Pop Art  0.978723   0.500000  0.111111  0.181818
# 10    Northern Renaissance  0.900709   0.346154  0.264706  0.300000
# 11                  Cubism  0.929078   0.214286  0.136364  0.166667
# 12               Mannerism  0.957447   0.400000  0.117647  0.181818
# ...

# %%
df_test_results[['true positives', 'false positives']].sum()
# Out:
# true positives     114.0
# false positives    142.0
# dtype: float64

# %%
df_train_results = pd.read_csv('C:\\Users\\gregf\\Desktop\\UFSCAR\\2022-2\\IA 2\\RecomendadorArtes\\src\\models\\model_saves\\SimpleNeuralNetwork\\results\\16_03_2023_09_43\\all_classes_results_train.csv')

# %%
df_train_results
# Out:
#                      genre  accuracy  precision    recall        f1  \
# 0            Byzantine Art  0.999003   0.921569  1.000000  0.959184
# 1           Abstractionism  0.998629   0.984615  0.973384  0.978967
# 2            Impressionism  0.993643   0.987418  0.984724  0.986069
# 3              Art Nouveau  0.998255   0.989899  0.882883  0.933333
# 4              Suprematism  0.999501   0.975410  0.991667  0.983471
# 5              Romanticism  0.998130   0.991643  0.967391  0.979367
# 6   Abstract Expressionism  1.000000   1.000000  1.000000  1.000000
# 7                  Realism  0.999751   1.000000  0.985816  0.992857
# 8        Early Renaissance  0.999501   0.975000  1.000000  0.987342
# 9                  Pop Art  0.999252   1.000000  0.965116  0.982249
# 10    Northern Renaissance  0.993768   0.961300  0.961300  0.961300
# 11                  Cubism  0.999501   0.997590  0.992806  0.995192
# 12               Mannerism  0.999501   1.000000  0.987692  0.993808
# ...

# %%
df_train_results[['true positives', 'false positives']].sum()
# Out:
# true positives     9708.0
# false positives     127.0
# dtype: float64

# %% [markdown]
# ### Resultados AlexNet

# %%
df_test_results = pd.read_csv('C:\\Users\\gregf\\Desktop\\UFSCAR\\2022-2\\IA 2\\RecomendadorArtes\\src\\models\\model_saves\\AlexNet\\results\\16_03_2023_21_08\\all_classes_results.csv')

# %%
df_test_results
# Out:
#                      genre  accuracy  precision    recall        f1  \
# 0            Byzantine Art  0.988180   0.000000  0.000000  0.000000
# 1           Abstractionism  0.969267   0.000000  0.000000  0.000000
# 2            Impressionism  0.768322   0.500000  0.051020  0.092593
# 3              Art Nouveau  0.985816   0.000000  0.000000  0.000000
# 4              Suprematism  0.985816   0.000000  0.000000  0.000000
# 5              Romanticism  0.964539   0.857143  0.300000  0.444444
# 6   Abstract Expressionism  0.997636   0.000000  0.000000  0.000000
# 7                  Realism  0.981087   0.000000  0.000000  0.000000
# 8        Early Renaissance  0.981087   0.000000  0.000000  0.000000
# 9                  Pop Art  0.978723   0.000000  0.000000  0.000000
# 10    Northern Renaissance  0.931442   0.586207  0.500000  0.539683
# 11                  Cubism  0.947991   0.000000  0.000000  0.000000
# 12               Mannerism  0.959811   0.500000  0.058824  0.105263
# ...

# %%
df_test_results[['true positives', 'false positives']].sum()
# Out:
# true positives     53.0
# false positives    37.0
# dtype: float64

# %%
df_train_results = pd.read_csv('C:\\Users\\gregf\\Desktop\\UFSCAR\\2022-2\\IA 2\\RecomendadorArtes\\src\\models\\model_saves\\AlexNet\\results\\16_03_2023_21_46\\all_classes_results_train.csv')

# %%
df_train_results
# Out:
#                      genre  accuracy  precision    recall        f1  \
# 0            Byzantine Art  0.988284   0.000000  0.000000  0.000000
# 1           Abstractionism  0.967219   0.000000  0.000000  0.000000
# 2            Impressionism  0.779758   0.683333  0.067103  0.122206
# 3              Art Nouveau  0.986165   0.000000  0.000000  0.000000
# 4              Suprematism  0.985043   0.000000  0.000000  0.000000
# 5              Romanticism  0.955752   0.542484  0.225543  0.318618
# 6   Abstract Expressionism  0.997133   0.000000  0.000000  0.000000
# 7                  Realism  0.982426   0.000000  0.000000  0.000000
# 8        Early Renaissance  0.980556   0.000000  0.000000  0.000000
# 9                  Pop Art  0.979933   0.823529  0.081395  0.148148
# 10    Northern Renaissance  0.935311   0.664935  0.396285  0.496605
# 11                  Cubism  0.948024   0.000000  0.000000  0.000000
# 12               Mannerism  0.961984   0.727273  0.098462  0.173442
# ...

# %%
df_train_results[['true positives', 'false positives']].sum()
# Out:
# true positives     1113.0
# false positives     475.0
# dtype: float64

# %% [markdown]
# ### Resultados ResNet

# %%
df_test_results = pd.read_csv('C:\\Users\\gregf\\Desktop\\UFSCAR\\2022-2\\IA 2\\RecomendadorArtes\\src\\models\\model_saves\\ResNet50\\results\\17_03_2023_05_32\\all_classes_results.csv')

# %%
df_test_results
# Out:
#                      genre  accuracy  precision    recall        f1  \
# 0            Byzantine Art  0.988180   0.000000  0.000000  0.000000
# 1           Abstractionism  0.971631   1.000000  0.076923  0.142857
# 2            Impressionism  0.791962   0.604167  0.295918  0.397260
# 3              Art Nouveau  0.985816   0.000000  0.000000  0.000000
# 4              Suprematism  0.985816   0.000000  0.000000  0.000000
# 5              Romanticism  0.955083   0.571429  0.200000  0.296296
# 6   Abstract Expressionism  0.997636   0.000000  0.000000  0.000000
# 7                  Realism  0.981087   0.000000  0.000000  0.000000
# 8        Early Renaissance  0.981087   0.000000  0.000000  0.000000
# 9                  Pop Art  0.976359   0.400000  0.222222  0.285714
# 10    Northern Renaissance  0.933806   0.800000  0.235294  0.363636
# 11                  Cubism  0.945626   0.000000  0.000000  0.000000
# 12               Mannerism  0.959811   0.000000  0.000000  0.000000
# ...

# %%
df_test_results[['true positives', 'false positives']].sum()
# Out:
# true positives     93.0
# false positives    91.0
# dtype: float64

# %%
df_train_results = pd.read_csv('C:\\Users\\gregf\\Desktop\\UFSCAR\\2022-2\\IA 2\\RecomendadorArtes\\src\\models\\model_saves\\ResNet50\\results\\17_03_2023_06_08\\all_classes_results_train.csv')

# %%
df_train_results
# Out:
#                      genre  accuracy  precision    recall        f1  \
# 0            Byzantine Art  0.988284   0.000000  0.000000  0.000000
# 1           Abstractionism  0.967344   0.509804  0.098859  0.165605
# 2            Impressionism  0.813038   0.654024  0.385706  0.485244
# 3              Art Nouveau  0.986165   0.000000  0.000000  0.000000
# 4              Suprematism  0.985043   0.000000  0.000000  0.000000
# 5              Romanticism  0.961361   0.768519  0.225543  0.348739
# 6   Abstract Expressionism  0.997009   0.428571  0.130435  0.200000
# 7                  Realism  0.982426   0.000000  0.000000  0.000000
# 8        Early Renaissance  0.980556   0.000000  0.000000  0.000000
# 9                  Pop Art  0.978312   0.481481  0.151163  0.230088
# 10    Northern Renaissance  0.937056   0.857868  0.261610  0.400949
# 11                  Cubism  0.948149   0.533333  0.019185  0.037037
# 12               Mannerism  0.959616   1.000000  0.003077  0.006135
# ...

# %%
df_train_results[['true positives', 'false positives']].sum()
# Out:
# true positives     1809.0
# false positives    1651.0
# dtype: float64
