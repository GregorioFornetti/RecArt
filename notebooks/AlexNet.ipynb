# %%
import sys
sys.path.append("..")
from src.models.utils.dataset_preprocess import preprocess_dataset
from src.models.classification_models.AlexNet import AlexNet

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
preprocess_dataset()

# %%
model = AlexNet(load=False)

# %%
classes_metrics, agg_metrics = model.fit_and_test()
# Out:
# Found 8023 validated image filenames.
# Epoch 1/10
# 251/251 [==============================] - 233s 920ms/step - loss: 0.1916 - accuracy: 0.2074
# Epoch 2/10
# 251/251 [==============================] - 228s 908ms/step - loss: 0.1765 - accuracy: 0.2181
# Epoch 3/10
# 251/251 [==============================] - 220s 875ms/step - loss: 0.1724 - accuracy: 0.2413
# Epoch 4/10
# 251/251 [==============================] - 226s 900ms/step - loss: 0.1667 - accuracy: 0.2580
# Epoch 5/10
# 251/251 [==============================] - 225s 894ms/step - loss: 0.1609 - accuracy: 0.2787
# Epoch 6/10
# 251/251 [==============================] - 224s 892ms/step - loss: 0.1573 - accuracy: 0.2953
# Epoch 7/10
# 251/251 [==============================] - 228s 906ms/step - loss: 0.1547 - accuracy: 0.3050
# Epoch 8/10
# 251/251 [==============================] - 224s 893ms/step - loss: 0.1516 - accuracy: 0.3172
# Epoch 9/10
# 251/251 [==============================] - 217s 866ms/step - loss: 0.1480 - accuracy: 0.3389
# Epoch 10/10
# 251/251 [==============================] - 218s 868ms/step - loss: 0.1449 - accuracy: 0.3357
# c:\Users\gregf\anaconda3\envs\RecArt\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\gregf\anaconda3\envs\RecArt\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\gregf\anaconda3\envs\RecArt\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\gregf\anaconda3\envs\RecArt\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\gregf\anaconda3\envs\RecArt\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\gregf\anaconda3\envs\RecArt\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\gregf\anaconda3\envs\RecArt\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\gregf\anaconda3\envs\RecArt\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\gregf\anaconda3\envs\RecArt\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\gregf\anaconda3\envs\RecArt\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\gregf\anaconda3\envs\RecArt\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\gregf\anaconda3\envs\RecArt\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\gregf\anaconda3\envs\RecArt\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\gregf\anaconda3\envs\RecArt\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\gregf\anaconda3\envs\RecArt\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
classes_metrics
# Out:
#                      genre  accuracy  precision    recall        f1  \
# 0            Byzantine Art  0.988180   0.000000  0.000000  0.000000
# 1           Abstractionism  0.969267   0.000000  0.000000  0.000000
# 2            Impressionism  0.768322   0.500000  0.051020  0.092593
# 3              Art Nouveau  0.985816   0.000000  0.000000  0.000000
# 4              Suprematism  0.985816   0.000000  0.000000  0.000000
# 5              Romanticism  0.964539   0.857143  0.300000  0.444444
# 6   Abstract Expressionism  0.997636   0.000000  0.000000  0.000000
# 7                  Realism  0.981087   0.000000  0.000000  0.000000
# 8        Early Renaissance  0.981087   0.000000  0.000000  0.000000
# 9                  Pop Art  0.978723   0.000000  0.000000  0.000000
# 10    Northern Renaissance  0.931442   0.586207  0.500000  0.539683
# 11                  Cubism  0.947991   0.000000  0.000000  0.000000
# 12               Mannerism  0.959811   0.500000  0.058824  0.105263
# 13      Post-Impressionism  0.799054   0.400000  0.073171  0.123711
# 14                Muralism  0.990544   0.000000  0.000000  0.000000
# 15       Proto Renaissance  0.985816   0.000000  0.000000  0.000000
# 16          Social Realism  0.990544   0.000000  0.000000  0.000000
# 17               Symbolism  0.919622   0.000000  0.000000  0.000000
# 18              Surrealism  0.914894   1.000000  0.027027  0.052632
# 19                 Baroque  0.945626   0.666667  0.413793  0.510638
# 20           Neoplasticism  0.990544   0.000000  0.000000  0.000000
# 21           Expressionism  0.938534   0.000000  0.000000  0.000000
# 22             Primitivism  0.952719   0.750000  0.136364  0.230769
# 23        High Renaissance  0.936170   0.500000  0.074074  0.129032
#
#     positive examples  true positives  false positives
# 0                 5.0             0.0              0.0
# 1                13.0             0.0              0.0
# 2                98.0             5.0              5.0
# 3                 6.0             0.0              0.0
# 4                 6.0             0.0              0.0
# 5                20.0             6.0              1.0
# 6                 1.0             0.0              0.0
# 7                 8.0             0.0              0.0
# 8                 8.0             0.0              0.0
# 9                 9.0             0.0              0.0
# 10               34.0            17.0             12.0
# 11               22.0             0.0              0.0
# 12               17.0             1.0              1.0
# 13               82.0             6.0              9.0
# 14                4.0             0.0              0.0
# 15                6.0             0.0              0.0
# 16                4.0             0.0              0.0
# 17               34.0             0.0              0.0
# 18               37.0             1.0              0.0
# 19               29.0            12.0              6.0
# 20                4.0             0.0              0.0
# 21               26.0             0.0              0.0
# 22               22.0             3.0              1.0
# 23               27.0             2.0              2.0

# %%
agg_metrics
# Out:
#    total examples  full hits  mean accuracy  micro precision  micro recall  \
# 0             423         43       0.950158         0.240001      0.068095
#
#    micro f1  macro precision  macro recall  macro f1
# 0  0.092865         0.588889      0.101533  0.173203

# %%
classes_metrics, agg_metrics = model.evaluate_train()
# Out:
# c:\Users\gregf\anaconda3\envs\RecArt\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\gregf\anaconda3\envs\RecArt\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\gregf\anaconda3\envs\RecArt\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\gregf\anaconda3\envs\RecArt\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\gregf\anaconda3\envs\RecArt\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\gregf\anaconda3\envs\RecArt\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\gregf\anaconda3\envs\RecArt\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\gregf\anaconda3\envs\RecArt\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\gregf\anaconda3\envs\RecArt\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\gregf\anaconda3\envs\RecArt\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\gregf\anaconda3\envs\RecArt\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\gregf\anaconda3\envs\RecArt\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\gregf\anaconda3\envs\RecArt\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\gregf\anaconda3\envs\RecArt\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
classes_metrics
# Out:
#                      genre  accuracy  precision    recall        f1  \
# 0            Byzantine Art  0.988284   0.000000  0.000000  0.000000
# 1           Abstractionism  0.967219   0.000000  0.000000  0.000000
# 2            Impressionism  0.779758   0.683333  0.067103  0.122206
# 3              Art Nouveau  0.986165   0.000000  0.000000  0.000000
# 4              Suprematism  0.985043   0.000000  0.000000  0.000000
# 5              Romanticism  0.955752   0.542484  0.225543  0.318618
# 6   Abstract Expressionism  0.997133   0.000000  0.000000  0.000000
# 7                  Realism  0.982426   0.000000  0.000000  0.000000
# 8        Early Renaissance  0.980556   0.000000  0.000000  0.000000
# 9                  Pop Art  0.979933   0.823529  0.081395  0.148148
# 10    Northern Renaissance  0.935311   0.664935  0.396285  0.496605
# 11                  Cubism  0.948024   0.000000  0.000000  0.000000
# 12               Mannerism  0.961984   0.727273  0.098462  0.173442
# 13      Post-Impressionism  0.810545   0.585000  0.075290  0.133409
# 14                Muralism  0.991774   0.000000  0.000000  0.000000
# 15       Proto Renaissance  0.985915   0.000000  0.000000  0.000000
# 16          Social Realism  0.991774   0.000000  0.000000  0.000000
# 17               Symbolism  0.921226   0.000000  0.000000  0.000000
# 18              Surrealism  0.915493   0.759259  0.058074  0.107895
# 19                 Baroque  0.955378   0.832776  0.447038  0.581776
# 20           Neoplasticism  0.990029   0.000000  0.000000  0.000000
# 21           Expressionism  0.936433   0.000000  0.000000  0.000000
# 22             Primitivism  0.959242   0.954545  0.206388  0.339394
# 23        High Renaissance  0.941543   0.678571  0.215501  0.327116
#
#     positive examples  true positives  false positives
# 0                94.0             0.0              0.0
# 1               263.0             0.0              0.0
# 2              1833.0           123.0             57.0
# 3               111.0             0.0              0.0
# 4               120.0             0.0              0.0
# 5               368.0            83.0             70.0
# 6                23.0             0.0              0.0
# 7               141.0             0.0              0.0
# 8               156.0             0.0              0.0
# 9               172.0            14.0              3.0
# 10              646.0           256.0            129.0
# 11              417.0             0.0              0.0
# 12              325.0            32.0             12.0
# 13             1554.0           117.0             83.0
# 14               66.0             0.0              0.0
# 15              113.0             0.0              0.0
# 16               66.0             0.0              0.0
# 17              632.0             0.0              0.0
# 18              706.0            41.0             13.0
# 19              557.0           249.0             50.0
# 20               80.0             0.0              0.0
# 21              510.0             0.0              0.0
# 22              407.0            84.0              4.0
# 23              529.0           114.0             54.0

# %%
agg_metrics
# Out:
#    total examples  full hits  mean accuracy  micro precision  micro recall  \
# 0            8023        865       0.951956         0.302154      0.077962
#
#    micro f1  macro precision  macro recall  macro f1
# 0  0.114525         0.700882      0.112549  0.193953

# %%
model.fit_full()
# Out:
# Found 8446 validated image filenames.
# Epoch 1/10
# 264/264 [==============================] - 276s 1s/step - loss: 0.1420 - accuracy: 0.3467
# Epoch 2/10
# 264/264 [==============================] - 281s 1s/step - loss: 0.1376 - accuracy: 0.3739
# Epoch 3/10
# 264/264 [==============================] - 268s 1s/step - loss: 0.1342 - accuracy: 0.3886
# Epoch 4/10
# 264/264 [==============================] - 267s 1s/step - loss: 0.1297 - accuracy: 0.3969
# Epoch 5/10
# 264/264 [==============================] - 410s 2s/step - loss: 0.1260 - accuracy: 0.4120
# Epoch 6/10
# 264/264 [==============================] - 378s 1s/step - loss: 0.1217 - accuracy: 0.4277
# Epoch 7/10
# 264/264 [==============================] - 274s 1s/step - loss: 0.1171 - accuracy: 0.4412
# Epoch 8/10
# 264/264 [==============================] - 265s 1s/step - loss: 0.1125 - accuracy: 0.4632
# Epoch 9/10
# 264/264 [==============================] - 253s 957ms/step - loss: 0.1101 - accuracy: 0.4809
# Epoch 10/10
# 264/264 [==============================] - 246s 930ms/step - loss: 0.1036 - accuracy: 0.5001

# %%
model.save_model()

# %%
model = AlexNet()

# %%
model.save_imgs_predictions()
# Out:
# 8446 de 8446

# %%
model.get_imgs_predictions()
# Out:
#       artist id                                         image path  \
# 0             0  c:\Users\gregf\Desktop\UFSCAR\2022-2\IA 2\Reco...
# 1             0  c:\Users\gregf\Desktop\UFSCAR\2022-2\IA 2\Reco...
# 2             0  c:\Users\gregf\Desktop\UFSCAR\2022-2\IA 2\Reco...
# 3             0  c:\Users\gregf\Desktop\UFSCAR\2022-2\IA 2\Reco...
# 4             0  c:\Users\gregf\Desktop\UFSCAR\2022-2\IA 2\Reco...
# ...         ...                                                ...
# 8441         49  c:\Users\gregf\Desktop\UFSCAR\2022-2\IA 2\Reco...
# 8442         49  c:\Users\gregf\Desktop\UFSCAR\2022-2\IA 2\Reco...
# 8443         49  c:\Users\gregf\Desktop\UFSCAR\2022-2\IA 2\Reco...
# 8444         49  c:\Users\gregf\Desktop\UFSCAR\2022-2\IA 2\Reco...
# 8445         49  c:\Users\gregf\Desktop\UFSCAR\2022-2\IA 2\Reco...