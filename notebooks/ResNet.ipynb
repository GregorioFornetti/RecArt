# %%
import sys
sys.path.append("..")
from src.models.utils.dataset_preprocess import preprocess_dataset
from src.models.classification_models.ResNet50 import ResNet50

# %%
# %load_ext autoreload
# %autoreload 2

# %%
preprocess_dataset()

# %%
model = ResNet50(load=False)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 model = ResNet50(load=False)
#
# File ~\Desktop\UFSCAR\2022-2\IA 2\RecomendadorArtes\src\models\classification_models\Model.py:58, in Model.__init__(self, load)
#      55 self._init_attributes()
#      56 self.__create_folders()
# ---> 58 self._create_neural_network()
#      59 if load:
#      60     self.model.load_weights(f'{self.save_path}/params/weights.h5')
#
# File c:\Users\gregf\Desktop\UFSCAR\2022-2\IA 2\RecomendadorArtes\notebooks\..\src\models\classification_models\ResNet50.py:23, in ResNet50._create_neural_network(self)
#      19 def _create_neural_network(self):
#      20     '''
#      21     Inicializa a estrutura da rede neural
#      22     '''
# ---> 23     self.model = tf.keras.applications.ResNet50(classes=self.OUTPUT_SIZE, weights="imagenet", input_shape=self.img_shape, classifier_activation='sigmoid')
#      24     self.model.compile(optimizer='adam',
#      25                        loss='binary_crossentropy',
#      26                        metrics=['accuracy'])
#
# File c:\Users\gregf\anaconda3\envs\RecArt\lib\site-packages\keras\applications\resnet.py:521, in ResNet50(include_top, weights, input_tensor, input_shape, pooling, classes, **kwargs)
#     518     x = stack1(x, 256, 6, name="conv4")
#     519     return stack1(x, 512, 3, name="conv5")
# --> 521 return ResNet(
#     522     stack_fn,
#     523     False,
#     524     True,
#     525     "resnet50",
#     526     include_top,
#     527     weights,
#     528     input_tensor,
#     529     input_shape,
#     530     pooling,
#     531     classes,
#     532     **kwargs
#     533 )
#
# File c:\Users\gregf\anaconda3\envs\RecArt\lib\site-packages\keras\applications\resnet.py:153, in ResNet(stack_fn, preact, use_bias, model_name, include_top, weights, input_tensor, input_shape, pooling, classes, classifier_activation, **kwargs)
#     145     raise ValueError(
#     146         "The `weights` argument should be either "
#     147         "`None` (random initialization), `imagenet` "
#     148         "(pre-training on ImageNet), "
#     149         "or the path to the weights file to be loaded."
#     150     )
#     152 if weights == "imagenet" and include_top and classes != 1000:
# --> 153     raise ValueError(
#     154         'If using `weights` as `"imagenet"` with `include_top`'
#     155         " as true, `classes` should be 1000"
#     156     )
#     158 # Determine proper input shape
#     159 input_shape = imagenet_utils.obtain_input_shape(
#     160     input_shape,
#     161     default_size=224,
#    (...)
#     165     weights=weights,
#     166 )
#
# ValueError: If using `weights` as `"imagenet"` with `include_top` as true, `classes` should be 1000

# %%
classes_metrics, agg_metrics = model.fit_and_test()
# Out:
# Found 8023 validated image filenames.
# Epoch 1/10
#  49/251 [====>.........................] - ETA: 1:11:43 - loss: 0.2277 - accuracy: 0.2500
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 classes_metrics, agg_metrics = model.fit_and_test()
#
# File ~\Desktop\UFSCAR\2022-2\IA 2\RecomendadorArtes\src\models\classification_models\Model.py:133, in Model.fit_and_test(self, batch_size, epochs)
#     106 '''
#     107 Treina o modelo para testes. Após executar, será salvo os resultados dos testes
#     108
#    (...)
#     130 um DataFrame de métricas gerais. Esses dois DataFrames serão salvos no "save_path" do modelo.
#     131 '''
#     132 train_gen = load_train_for_test_generator((self.img_shape[0], self.img_shape[1]))
# --> 133 self.history = self.model.fit(train_gen, batch_size=batch_size, epochs=epochs)
#     134 return self.evaluate()
#
# File c:\Users\gregf\anaconda3\envs\RecArt\lib\site-packages\keras\utils\traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\gregf\anaconda3\envs\RecArt\lib\site-packages\keras\engine\training.py:1564, in Model.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1556 with tf.profiler.experimental.Trace(
#    1557     "train",
#    1558     epoch_num=epoch,
#    (...)
#    1561     _r=1,
#    1562 ):
#    1563     callbacks.on_train_batch_begin(step)
# -> 1564     tmp_logs = self.train_function(iterator)
#    1565     if data_handler.should_sync:
#    1566         context.async_wait()
#
# File c:\Users\gregf\anaconda3\envs\RecArt\lib\site-packages\tensorflow\python\util\traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\gregf\anaconda3\envs\RecArt\lib\site-packages\tensorflow\python\eager\def_function.py:915, in Function.__call__(self, *args, **kwds)
#     912 compiler = "xla" if self._jit_compile else "nonXla"
#     914 with OptionalXlaContext(self._jit_compile):
# --> 915   result = self._call(*args, **kwds)
#     917 new_tracing_count = self.experimental_get_tracing_count()
#     918 without_tracing = (tracing_count == new_tracing_count)
#
# File c:\Users\gregf\anaconda3\envs\RecArt\lib\site-packages\tensorflow\python\eager\def_function.py:947, in Function._call(self, *args, **kwds)
#     944   self._lock.release()
#     945   # In this case we have created variables on the first call, so we run the
#     946   # defunned version which is guaranteed to never create variables.
# --> 947   return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     948 elif self._stateful_fn is not None:
#     949   # Release the lock early so that multiple threads can perform the call
#     950   # in parallel.
#     951   self._lock.release()
#
# File c:\Users\gregf\anaconda3\envs\RecArt\lib\site-packages\tensorflow\python\eager\function.py:2496, in Function.__call__(self, *args, **kwargs)
#    2493 with self._lock:
#    2494   (graph_function,
#    2495    filtered_flat_args) = self._maybe_define_function(args, kwargs)
# -> 2496 return graph_function._call_flat(
#    2497     filtered_flat_args, captured_inputs=graph_function.captured_inputs)
#
# File c:\Users\gregf\anaconda3\envs\RecArt\lib\site-packages\tensorflow\python\eager\function.py:1862, in ConcreteFunction._call_flat(self, args, captured_inputs, cancellation_manager)
#    1858 possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    1859 if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    1860     and executing_eagerly):
#    1861   # No tape is watching; skip to running the function.
# -> 1862   return self._build_call_outputs(self._inference_function.call(
#    1863       ctx, args, cancellation_manager=cancellation_manager))
#    1864 forward_backward = self._select_forward_and_backward_functions(
#    1865     args,
#    1866     possible_gradient_type,
#    1867     executing_eagerly)
#    1868 forward_function, args_with_tangents = forward_backward.forward()
#
# File c:\Users\gregf\anaconda3\envs\RecArt\lib\site-packages\tensorflow\python\eager\function.py:499, in _EagerDefinedFunction.call(self, ctx, args, cancellation_manager)
#     497 with _InterpolateFunctionError(self):
#     498   if cancellation_manager is None:
# --> 499     outputs = execute.execute(
#     500         str(self.signature.name),
#     501         num_outputs=self._num_outputs,
#     502         inputs=args,
#     503         attrs=attrs,
#     504         ctx=ctx)
#     505   else:
#     506     outputs = execute.execute_with_cancellation(
#     507         str(self.signature.name),
#     508         num_outputs=self._num_outputs,
#    (...)
#     511         ctx=ctx,
#     512         cancellation_manager=cancellation_manager)
#
# File c:\Users\gregf\anaconda3\envs\RecArt\lib\site-packages\tensorflow\python\eager\execute.py:54, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      52 try:
#      53   ctx.ensure_initialized()
# ---> 54   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      55                                       inputs, attrs, num_outputs)
#      56 except core._NotOkStatusException as e:
#      57   if name is not None:
#
# KeyboardInterrupt:

# %%
classes_metrics
# Out:
#                      genre  accuracy  precision  recall   f1
# 0            Byzantine Art  0.988180        0.0     0.0  0.0
# 1           Abstractionism  0.969267        0.0     0.0  0.0
# 2            Impressionism  0.768322        0.0     0.0  0.0
# 3              Art Nouveau  0.985816        0.0     0.0  0.0
# 4              Suprematism  0.985816        0.0     0.0  0.0
# 5              Romanticism  0.952719        0.0     0.0  0.0
# 6   Abstract Expressionism  0.997636        0.0     0.0  0.0
# 7                  Realism  0.981087        0.0     0.0  0.0
# 8        Early Renaissance  0.981087        0.0     0.0  0.0
# 9                  Pop Art  0.978723        0.0     0.0  0.0
# 10    Northern Renaissance  0.919622        0.0     0.0  0.0
# 11                  Cubism  0.947991        0.0     0.0  0.0
# 12               Mannerism  0.959811        0.0     0.0  0.0
# 13      Post-Impressionism  0.806147        0.0     0.0  0.0
# 14                Muralism  0.990544        0.0     0.0  0.0
# 15       Proto Renaissance  0.985816        0.0     0.0  0.0
# 16          Social Realism  0.990544        0.0     0.0  0.0
# 17               Symbolism  0.919622        0.0     0.0  0.0
# 18              Surrealism  0.912530        0.0     0.0  0.0
# 19                 Baroque  0.931442        0.0     0.0  0.0
# 20           Neoplasticism  0.990544        0.0     0.0  0.0
# 21           Expressionism  0.938534        0.0     0.0  0.0
# 22             Primitivism  0.947991        0.0     0.0  0.0
# 23        High Renaissance  0.936170        0.0     0.0  0.0

# %%
agg_metrics
# Out:
#    mean accuracy  micro precision  micro recall  micro f1  macro precision  \
# 0       0.948582              0.0           0.0       0.0              NaN
#
#    macro recall  macro f1
# 0           0.0       NaN

# %%
model.fit_full()
# Out:
# Found 8446 validated image filenames.
# Epoch 1/10
# 264/264 [==============================] - 235s 892ms/step - loss: 0.1786 - accuracy: 0.2175
# Epoch 2/10
# 264/264 [==============================] - 237s 898ms/step - loss: 0.1786 - accuracy: 0.2203
# Epoch 3/10
# 264/264 [==============================] - 229s 867ms/step - loss: 0.1784 - accuracy: 0.2208
# Epoch 4/10
# 264/264 [==============================] - 230s 869ms/step - loss: 0.1786 - accuracy: 0.2214
# Epoch 5/10
# 264/264 [==============================] - 232s 878ms/step - loss: 0.1786 - accuracy: 0.2226
# Epoch 6/10
# 264/264 [==============================] - 234s 884ms/step - loss: 0.1786 - accuracy: 0.2187
# Epoch 7/10
# 264/264 [==============================] - 234s 887ms/step - loss: 0.1786 - accuracy: 0.2180
# Epoch 8/10
# 264/264 [==============================] - 230s 870ms/step - loss: 0.1787 - accuracy: 0.2263
# Epoch 9/10
# 264/264 [==============================] - 228s 865ms/step - loss: 0.1787 - accuracy: 0.2206
# Epoch 10/10
# 264/264 [==============================] - 226s 857ms/step - loss: 0.1785 - accuracy: 0.2168

# %%
model.save_model()

# %%
model = ResNet50()

# %%
model.save_imgs_predictions()
# Out:
# 8446 de 8446

# %%
model.get_imgs_predictions()
# Out:
#       artist id                                         image path  \
# 0             0  c:\Users\gregf\Desktop\UFSCAR\2022-2\IA 2\Reco...
#